# %% [markdown]
# Write a program to implement a simple form of a recurrent neural network.
# **a**. E.g. (4-to-1 RNN) to show that the quantity of rain on a certain day also depends on the values of the previous day

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Define sequence of 50 days of rain data
rain_data = np.array([2.3, 1.5, 3.1, 2.0, 2.5, 1.7, 2.9, 3.5, 3.0, 2.1,
                      2.5, 2.2, 2.8, 3.2, 1.8, 2.7, 1.9, 3.1, 3.3, 2.0,
                      2.5, 2.2, 2.4, 3.0, 2.1, 2.5, 3.2, 3.1, 1.9, 2.7,
                      2.2, 2.8, 3.1, 2.0, 2.5, 1.7, 2.9, 3.5, 3.0, 2.1,
                      2.5, 2.2, 2.8, 3.2, 1.8, 2.7, 1.9, 3.1, 3.3, 2.0])

# Create input and output sequences for training
time_steps = 4
x_train = np.array([rain_data[i:i+time_steps] for i in range(len(rain_data)-time_steps)])
y_train = rain_data[time_steps:]

# Define RNN model
model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(8, input_shape=(time_steps, 1)),
    tf.keras.layers.Dense(1)
])

# Compile and train model
model.compile(optimizer="adam", loss="mse")
history = model.fit(x_train.reshape(-1, time_steps, 1), y_train, epochs=100)

# Plot loss over time
plt.plot(history.history["loss"], "bo", label="Training loss")
plt.title("Training loss")
plt.legend()
plt.show()

# Test model on new sequence
test_sequence = np.array([2.5, 2.2, 2.8, 3.2])
x_test = np.array([test_sequence])
y_test = model.predict(x_test.reshape(-1, time_steps, 1))

# Print input, output, and prediction
print("Previous days' rain data:", test_sequence)
print("Expected rain amount for next day:", y_test[0][0])
prediction = model.predict(np.array([test_sequence]).reshape(1, time_steps, 1))
print("Prediction:", prediction[0][0])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 17ms/step - loss: 2.9181
# Epoch 2/100
# 2/2 [==============================] - 0s 14ms/step - loss: 2.7300
# Epoch 3/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.5518
# Epoch 4/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.3911
# Epoch 5/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.2320
# Epoch 6/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.0870
# Epoch 7/100
# 2/2 [==============================] - 0s 14ms/step - loss: 1.9481
# Epoch 8/100
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8242
# Epoch 9/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.7064
# Epoch 10/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.5961
# Epoch 11/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.4939
# Epoch 12/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3965
# Epoch 13/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3105
# Epoch 14/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2292
# Epoch 15/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1524
# Epoch 16/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.0831
# Epoch 17/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0152
# Epoch 18/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9573
# Epoch 19/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9014
# Epoch 20/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8482
# Epoch 21/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8014
# Epoch 22/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7556
# Epoch 23/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7136
# Epoch 24/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6796
# Epoch 25/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6425
# Epoch 26/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6098
# Epoch 27/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5814
# Epoch 28/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5528
# Epoch 29/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5277
# Epoch 30/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5040
# Epoch 31/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4848
# Epoch 32/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4642
# Epoch 33/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4457
# Epoch 34/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4300
# Epoch 35/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4135
# Epoch 36/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4005
# Epoch 37/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3877
# Epoch 38/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3761
# Epoch 39/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3655
# Epoch 40/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3563
# Epoch 41/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3465
# Epoch 42/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3392
# Epoch 43/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3306
# Epoch 44/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3257
# Epoch 45/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3194
# Epoch 46/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3132
# Epoch 47/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3089
# Epoch 48/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3042
# Epoch 49/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3010
# Epoch 50/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2967
# Epoch 51/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2940
# Epoch 52/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2914
# Epoch 53/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2889
# Epoch 54/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2872
# Epoch 55/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2849
# Epoch 56/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2833
# Epoch 57/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2823
# Epoch 58/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2806
# Epoch 59/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2799
# Epoch 60/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2789
# Epoch 61/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2784
# Epoch 62/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2773
# Epoch 63/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2767
# Epoch 64/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2764
# Epoch 65/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2758
# Epoch 66/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2756
# Epoch 67/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2752
# Epoch 68/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2749
# Epoch 69/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2746
# Epoch 70/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2744
# Epoch 71/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2741
# Epoch 72/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2741
# Epoch 73/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2740
# Epoch 74/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2737
# Epoch 75/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2736
# Epoch 76/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2735
# Epoch 77/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2735
# Epoch 78/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2733
# Epoch 79/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2733
# Epoch 80/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2731
# Epoch 81/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2732
# Epoch 82/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2729
# Epoch 83/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2729
# Epoch 84/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2728
# Epoch 85/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2727
# Epoch 86/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2727
# Epoch 87/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2727
# Epoch 88/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2725
# Epoch 89/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2725
# Epoch 90/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2724
# Epoch 91/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2723
# Epoch 92/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2722
# Epoch 93/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2721
# Epoch 94/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2721
# Epoch 95/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2720
# Epoch 96/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2719
# Epoch 97/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2718
# Epoch 98/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2717
# Epoch 99/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2716
# Epoch 100/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2716
# 1/1 [==============================] - 0s 180ms/step
# Previous days' rain data: [2.5 2.2 2.8 3.2]
# Expected rain amount for next day: 2.6049614
# 1/1 [==============================] - 0s 23ms/step
# Prediction: 2.6049614

# %% [markdown]
# **b.** LSTM for sentiment analysis on datasets like UMICH SI650 for similar

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv("training.txt", delimiter="\t", names=["label", "text"])
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data["text"],data["label"], test_size=0.2, random_state=42)

# Tokenize words
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train)

# Convert words to sequences
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

# Pad sequences to have same length
max_length = 100
X_train_pad = pad_sequences(X_train_seq, maxlen=max_length, padding="post",truncating="post")
X_test_pad = pad_sequences(X_test_seq, maxlen=max_length, padding="post",truncating="post")

# Build LSTM model
model = tf.keras.models.Sequential([
tf.keras.layers.Embedding(input_dim=5000, output_dim=32,input_length=max_length),
tf.keras.layers.LSTM(units=64, dropout=0.2, recurrent_dropout=0.2),
tf.keras.layers.Dense(1, activation="sigmoid")
])

# Compile model
model.compile(optimizer="adam", loss="binary_crossentropy",metrics=["accuracy"])

# Train model
history = model.fit(X_train_pad, y_train, epochs=10, batch_size=32,validation_split=0.1)

# Evaluate model on test data
loss, accuracy = model.evaluate(X_test_pad, y_test)
print("Test loss:", loss)
print("Test accuracy:", accuracy)

# Plot training and validation accuracy over time
plt.plot(history.history["accuracy"], label="Training accuracy")
plt.plot(history.history["val_accuracy"], label="Validation accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Make predictions on test data
predictions = model.predict(X_test_pad)

# Print input, output, and prediction for random example
index = np.random.randint(0, len(X_test_pad))
text = tokenizer.sequences_to_texts([X_test_pad[index]])[0]
label = y_test.values[index]
prediction = predictions[index][0]
print("Text:", text)
print("Actual label:", label)
print("Predicted label:", round(prediction))
# Out:
# Epoch 1/10
# 156/156 [==============================] - 31s 175ms/step - loss: 0.6845 - accuracy: 0.5695 - val_loss: 0.6877 - val_accuracy: 0.5523
# Epoch 2/10
# 156/156 [==============================] - 27s 174ms/step - loss: 0.6840 - accuracy: 0.5689 - val_loss: 0.6878 - val_accuracy: 0.5523
# Epoch 3/10
# 156/156 [==============================] - 28s 179ms/step - loss: 0.6841 - accuracy: 0.5689 - val_loss: 0.6879 - val_accuracy: 0.5523
# Epoch 4/10
# 156/156 [==============================] - 27s 174ms/step - loss: 0.6844 - accuracy: 0.5689 - val_loss: 0.6878 - val_accuracy: 0.5523
# Epoch 5/10
# 156/156 [==============================] - 27s 173ms/step - loss: 0.6842 - accuracy: 0.5689 - val_loss: 0.6879 - val_accuracy: 0.5523
# Epoch 6/10
# 156/156 [==============================] - 27s 174ms/step - loss: 0.6841 - accuracy: 0.5691 - val_loss: 0.6886 - val_accuracy: 0.5523
# Epoch 7/10
# 156/156 [==============================] - 27s 171ms/step - loss: 0.6839 - accuracy: 0.5693 - val_loss: 0.6878 - val_accuracy: 0.5523
# Epoch 8/10
# 156/156 [==============================] - 27s 171ms/step - loss: 0.6839 - accuracy: 0.5693 - val_loss: 0.6885 - val_accuracy: 0.5523
# Epoch 9/10
# 156/156 [==============================] - 27s 172ms/step - loss: 0.6838 - accuracy: 0.5693 - val_loss: 0.6883 - val_accuracy: 0.5523
# Epoch 10/10
# 156/156 [==============================] - 27s 175ms/step - loss: 0.6710 - accuracy: 0.5926 - val_loss: 0.6889 - val_accuracy: 0.5523
# 44/44 [==============================] - 1s 22ms/step - loss: 0.6800 - accuracy: 0.5809
# Test loss: 0.6800422668457031
# Test accuracy: 0.5809248685836792
# 44/44 [==============================] - 1s 21ms/step
# Text: mission impossible 2 rocks <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV> <OOV>
# Actual label: 1
# Predicted label: 1
